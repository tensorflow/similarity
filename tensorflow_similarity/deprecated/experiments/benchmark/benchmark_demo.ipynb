# %%
# import tensorflow similarity benchmark subpackage
from tensorflow_similarity.benchmark import read_config_file, run_experiment

# %%
# the config file contains configuration for multiple experiments
# each line of the config file is a 
configs_path = "config.json"

# %%
configs = read_config_file(configs_path)

# %%
configs
# Out:
# [{'num_epochs': 20,
#   'num_unseen_classes': [5, 20],
#   'num_targets': [1, 5],
#   'output_path': '/usr/local/google/home/shunlin/similarity/tensorflow_similarity/experiments/benchmark/benchmark_20191209_104037',
#   'tower_model_architecture': 'VGG16',
#   'similarity_loss': 'triplet_loss',
#   'embedding_size': 32,
#   'percentage_training_class': 0.1,
#   'dataset': 'mini_imagenet'},
#  {'num_epochs': 20,
#   'num_unseen_classes': [5, 20],
#   'num_targets': [1, 5],
#   'output_path': '/usr/local/google/home/shunlin/similarity/tensorflow_similarity/experiments/benchmark/benchmark_20191209_104037',
#   'tower_model_architecture': 'VGG16',
#   'similarity_loss': 'triplet_loss',
#   'embedding_size': 32,
#   'percentage_training_class': 0.1,
#   'dataset': 'omniglot'},
#  {'num_epochs': 20,
#   'num_unseen_classes': [5, 20],
#   'num_targets': [1, 5],
# ...

# %%
for config in configs:
    run_experiment(config)
# Out:
# Model: "triplet_loss"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# anchor_image (InputLayer)       [(None, 84, 84, 3)]  0
# __________________________________________________________________________________________________
# anchor_idx (InputLayer)         [(None, 1)]          0
# __________________________________________________________________________________________________
# neg_image (InputLayer)          [(None, 84, 84, 3)]  0
# __________________________________________________________________________________________________
# neg_idx (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# pos_image (InputLayer)          [(None, 84, 84, 3)]  0
# __________________________________________________________________________________________________
# ...
